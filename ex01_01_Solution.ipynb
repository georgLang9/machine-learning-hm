# %% [markdown]
# # Maschinelles Lernens
# # Aufgabenblatt 01 - Aufgabe 01
# # Prof. Dr. David Spieler

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from pandas.plotting import scatter_matrix

# %%
df = pd.read_csv('College.csv')

# %%
df
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %% [markdown]
# # Aufgabe 1.3
# Ein Pandas DataFrame ist eine tabellenartige Datenstruktur. Die Spalten reprästentieren die einzelnen Features und jedes Datum wird in einer extra Zeile abgelegt.

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# # Aufgabe 1.5
# Für jedes numerische Feature werden individuelle Metriken berechnet.
# - count: Anzahl der Datenpunkte
# - mean: Mittelwert
# - std: Standardabweichung
# - min: Minimum
# - max: Maximum
# - 25%, 50%, 75%: Quantile, d.h. 25%, 50%, 75% der Datenpunkte sind unter diesem Wert, das 50%-Quantil ist auch der Median

# %%
df10 = df[df.columns[:10]]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Private', 'Apps', 'Accept', 'Enroll', 'Top10perc',
#        'Top25perc', 'F.Undergrad', 'P.Undergrad', 'Outstate', 'Room.Board',
#        'Books', 'Personal', 'PhD', 'Terminal', 'S.F.Ratio', 'perc.alumni',
#        'Expend', 'Grad.Rate'],
#       dtype='object')

# %%
sm = scatter_matrix(df10)

# %% [markdown]
# # Aufgabe 1.8
# Die Methode scatter_matrix erstellt eine Matrix aus Scatterplots, wie jedes Feature gegen jedes andere geplottet wird. In der Diagonalen befinden sich Histogramme der entsprechenden Features.

# %%
sm = scatter_matrix(df10, figsize=(15,15), s=5, marker='D')

# %% [markdown]
# # Aufgabe 1.9
# - figsize=(15,15) setzt die Größe der Abbildung auf 15x15 Zoll
# - s=50 setzt die Größer der Punkte in den Scatterplots auf 50
# - marker='D' setzt die Punktform in den Scatterplots auf Diamant

# %%
plt.boxplot(df['Outstate'], whis=1.5)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2068854cb70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x20688557470>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2068854ca20>],
#  'medians': [<matplotlib.lines.Line2D at 0x20688557cc0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2068855e128>],
#  'means': []}

# %% [markdown]
# # Aufgabe 1.11
# Der Boxplot visualisiert Metriken wie in df.describe() berechnet.
# - Die rote Linie ist der Median.
# - Die Box repräsentiert den Interquartilsabstand (IQR), in ihm befinden sich der Größe nach sortiert die mittleren 50% der Daten.
# - Der oberer whisker geht bis zum letzten Datum kleiner als Q3 + 1.5 x IQR. Der untere whisker geht bis zum ersten Datum größer als Q1 - 1.5 x IQR.
# - Die beiden Whisker dienen der Erkennung von Ausreissern, wie dem ungewöhnlich hohen Datenpunkt eingezeichnet als Kreis oben im Plot.

# %%
sns.countplot(x='Private', data=df)

# %% [markdown]
# # Aufgabe 1.13
# Ungefähr zwei von drei Hochschulen im Datensatz sind privat.

# %%
df['Elite'] = df.apply(lambda row: row['Top10perc'] > 50, axis=1)

# %%
df
# Out:
#                                   Unnamed: 0 Private   Apps  Accept  Enroll  \
# 0               Abilene Christian University     Yes   1660    1232     721
# 1                         Adelphi University     Yes   2186    1924     512
# 2                             Adrian College     Yes   1428    1097     336
# 3                        Agnes Scott College     Yes    417     349     137
# 4                  Alaska Pacific University     Yes    193     146      55
# 5                          Albertson College     Yes    587     479     158
# 6                    Albertus Magnus College     Yes    353     340     103
# 7                             Albion College     Yes   1899    1720     489
# 8                           Albright College     Yes   1038     839     227
# 9                  Alderson-Broaddus College     Yes    582     498     172
# 10                         Alfred University     Yes   1732    1425     472
# ...

# %%
sns.countplot(x='Elite', data=df)

# %% [markdown]
# # Aufgabe 1.16
# Es gibt ca. 80 Elite-Hochschulen.
