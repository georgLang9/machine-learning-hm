# %%
import pandas
import statistics
import seaborn
import matplotlib.pyplot

data = pandas.read_csv("./College.csv")
print(data)
# Out:
# 9990
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 772    False
# 773    False
# 774    False
# 775     True
# 776    False
# Name: Elite, Length: 777, dtype: bool

# %%
extracted = data[slice(10)]
pandas.plotting.scatter_matrix(extracted, figsize=(15,15), s=50, marker='D')

# %%
outstate = data['Outstate']
matplotlib.pyplot.boxplot(outstate)
# Out:
# 9990

# %%
seaborn.countplot(x='Private', data=data)

# %%
newStudents = data['Enroll']
top10 = data['Top10perc']
data['Elite'] = top10 >= 50
seaborn.countplot(x='Elite', data=data)

elite =  [elite for elite in data['Elite'] if elite]
elitePer = len(elite) / len(data) * 100
print(elitePer)
# Out:
# 10.682110682110682
